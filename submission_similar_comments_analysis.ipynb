# %% [markdown]
# # Latent Semantics Indexing
#
# In this notebook, we took a deep-dive of the data by localizing dataset into subgroups with seed comments (feature positive and toxic) and comments that are neighboring in meaning.

# %%
# Mount google drive
# Colab initialization
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/My\ Drive/ResponsibleDSProject

# %%
# !pip install gensim

# %%
# !pip install spacy

# %%
import pandas as pd
import gensim
from gensim import corpora
from collections import defaultdict

# %%
tp_csv=pd.read_csv('./test_public_expanded.csv')

# %%
submission_csv=pd.read_csv('./submission.csv')

# %% [markdown]
# ## Tokenization
#
# We perform a reasonable English-language tokenization with Spacy library

# %%
from spacy.lang.en import English
nlp = English()
tokenizer = nlp.Defaults.create_tokenizer(nlp)

# %%
tokens=[tokenizer(t) for t in tp_csv['comment_text']]

# %%
texts=[[str(t) for t in tt] for tt in tokens]

# %% [markdown]
# ## Build BoW

# %%
dictionary = corpora.Dictionary(texts)

# %%
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
import pickle

# %%
pickle.dump(corpus, open('./corpus.p', mode='wb'))

# %% [markdown]
# ## Build LSI

# %%
from gensim import models
# lsi = models.LsiModel(corpus, id2word=dictionary, num_topics=100)
lsi = models.LsiModel.load('./test_public.lsi')
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:253: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
from gensim import similarities
# index = similarities.MatrixSimilarity(lsi[corpus])
index = similarities.MatrixSimilarity.load('./test_public_lsi.index')
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:253: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
# index.save('./test_public_lsi.index')

# %%
# lsi.save('./test_public.lsi')

# %%
# Find comments similar to comment #4
sorted(enumerate(index[lsi[corpus[4]]]), key=lambda x: -x[1])[:10]
# Out:
# [(4, 1.0),
#  (15272, 0.902352),
#  (72394, 0.896707),
#  (14215, 0.8951077),
#  (38752, 0.89465356),
#  (55210, 0.89427745),
#  (44697, 0.8942518),
#  (94837, 0.89416766),
#  (11381, 0.89395434),
#  (96973, 0.89297175)]

# %%
tp_csv['comment_text'][15272]
# Out:
# 'SAA is a smaller scale duplicate of south africa. Cader deployment, corrupt leader, tender fraud, dodgy finance deals, huge consultant fees, rotating management, personal enrichment, friends in right places, total incompetence and protection from structures. All in all a lost opportunity never to be made up.'

# %%
submission_csv['prediction'][15272]
# Out:
# 0.8302916854619979

# %%
submission_csv[(submission_csv['prediction']>0.5) & (tp_csv['female'] > 0.5)]
# Out:
#             id  prediction
# 103    7000103    1.028124
# 206    7000206    1.022033
# 323    7000323    0.507464
# 387    7000387    1.793566
# 401    7000401    1.793887
# ...        ...         ...
# 96833  7096833    1.463537
# 96836  7096836    0.656292
# 96911  7096911    1.894577
# 97122  7097122    0.969890
# 97285  7097285    1.978591
#
# [995 rows x 2 columns]

# %% [markdown]
# ## Take a look at sample result of similairty

# %%
sorted(enumerate(index[lsi[corpus[96833]]]), key=lambda x: -x[1])[:10]
# Out:
# [(96833, 1.0000002),
#  (18928, 0.94458133),
#  (9349, 0.93294656),
#  (72730, 0.93000424),
#  (84210, 0.9226103),
#  (49854, 0.9159316),
#  (53357, 0.9152851),
#  (67705, 0.9141499),
#  (11213, 0.910691),
#  (47842, 0.91062266)]

# %%
for (i, sim) in sorted(enumerate(index[lsi[corpus[96833]]]), key=lambda x: -x[1])[:10]:
    print(tp_csv['id'][i], i, tp_csv['comment_text'][i], sim, submission_csv['prediction'][i], tp_csv['female'][i])
# Out:
# 7096833 96833 No, I love Queen Elizabeth, she also gave the United States, 1 Acre of Land at Runnymede England. You must not see the difference between certain women, and certain whores. You know, the oldest profession know to mankind.
#
# Did you read that Opinion from a Real COURT?
# 1215 the Magna Charta Property, just in case your missing a Flag.
# "John, by the grace of God, king of England, lord of Ireland, duke of Normandy and Aquitaine, and count of Anjou, to the archbishop, bishops, abbots, earls, barons, justiciaries, foresters, sheriffs, stewards, servants, and to all his bailiffs and liege subjects, greetings...."
#
# JFK didn't experience Domestic Violence either? Where the hell did you go to school?
#
# https://www.youtube.com/watch?v=Mp9EBvutfIo 1.0000002 1.4635372877120971 0.6000000000000001
# 7018928 18928 Lack of sidewalks, lack of adequate sidewalks, lack of protection, lack of shade, cars blowing past, no ROW buffer between the street and the sidewalk, wide street crossings, not enough cross walks, having to press a button to be able to cross the street, poor lighting, pollution.
#
# You couldn't come up with anything? 0.94458133 0.04044285491108894 nan
# 7009349 9349 After reading through most of the comments I continue to be horrified by the people defending Donald "Grab Her By the Pussy" Trump!. They continue to defend a man who may be the biggest piece of white trash America has produced yet! His accomplishments are: Lying, cheating on wives, lusting after his own daughter and calling her a piece of ass, groping his daughter in public, scamming investors out of millions with fake real estate deals and fake Trump U, multiple bankruptcies and failed companies, bankrupting many Mom & Pop businesses by not paying his bills, not paying employees, lying constantly about anything he doesn't know about; which is EVERYTHING, racism, misogyny, bigotry, vulgarity, bullying, sexual assault, narcissism, fake charities, insurance scams, tax evasion, stupidity, ignorance, brutality, the mental maturity of an 8 year old, , etc., etc., ad nauseum! I'm sure I left a lot off the list. Ran out of room!  Is this POS really your hero? 0.93294656 2.660240387916565 0.6000000000000001
# 7072730 72730 To the contrary, Mr. Williams, I look forward to electing the school board slate of Graziano, Holtzmann, Leung, and Schor, who will restore former levels of excellence to ALL Douglas County schools, not just the coddled charter schools. 0.93000424 0.023317949008196597 nan
# 7084210 84210 The Catholic church now recognizes among the ordained: deacons, priests, Chaplains of His Holiness, Honorary Prelates, Supernumerary Apostolic Protonotaries (no kidding....), bishops, archbishops, cardinal deacons, cardinal priests, cardinal bishops, and of course, the two popes -- all of which can be found in chapter nine of the Gospel according to Medieval Monarchy. 0.9226103 0.05941360630095005 0.0
# 7049854 49854 Once again, trying to make every election outcome either an indictment for or against Trump, regardless from the right or left is folly. IMO, I believe honest, sensible Americans, right, left, and center, are starting to consider what is best  for the COUNTRY, AMERICA, and not just the Dems. or Repubs., especially in light if the pervasive anger, hatred, hysteria, verbal abuse, physical violence, mortal violence, resistance, obstruction, unwarranted media vengeance, that the left perpetrates every minute of every day from every angle. Good Americans, regardless of party, especially the 'forgotten deplorables,' merely want to have a decent job, earn a decent living, and raise a decent family. Of course, there are lunatics and radicals from both sides, but Americans are fed up with the 'hatred' sucking the air out of daily life, and the more the 'left' does it, IMO, the more they are going to be blamed and held accountable. IMO, last night in GA. was a prime example. 0.9159316 0.7670480728149414 nan
# 7053357 53357 I think I know what's going on here.
# Flint, Michigan, in order to pay for more welfare queens, has taken to selling their infamous water.
#
#  And, in order to garner free publicity, they've sent a case to all of the newspaper reporters in the country who, naturally, will drink anything that is put before them, particularly if it looks like whiskey, and their water, as we all know, surely does.
#
#  Alas, besides the look of bourbon, it contains a tiny parasite, which effects the mind of those drinking it, and we've seen the results, haven't we?
# First there was the claim that the Hildebeast was the greatest thing since sliced bread, then the Russian non collusion, and now their diseased minds are insisting that a woman, and man, boring as all get out, should have an injection of free publicity, in order to pay for their wedding  and, I would imagine, divorce, in the not too distant future. 0.9152851 0.5771992489695549 0.833333333333333
# 7067705 67705 Well said, Conrad Black
#
# Following the rout of the international left at the hands of conservative leaders,
#
#  Reagan, Thatcher, John Paul II, Kohl, and Brian Mulroney,
#
#  and the disintegration of international communism and end of the Cold War, the entire left, from soft to Stalinist, crowded aboard the environment bandwagon.
#
# "Up to this point, this was a conservationist movement decrying pollution and grumbling about goodwill visits of nuclear aircraft carriers to Vancouver. Greenpeace, the Sierra Club, World Wildlife Fund, and others had given form and mass to disparate groups of birdwatchers, butterfly collectors, big game enthusiasts, and aggrieved complainants about inadequate drinking water and the depredations of industrial smoke and waste"
#
# "We’re six months into the Trudeau government — and so far, so good" - Conrad Black - National Post - Apr 9, 2016 0.9141499 0.07269601859152316 nan
# 7011213 11213 What exactly is the "extreme left wing"?  Is it support of social security, medicare, affordable health insurance, public education, intelligent diplomacy, clean air and water, safeguards for the foods we consume, regulation of financial institutions, union rights, womens' rights, minority rights, and voting rights?  If you don't believe in those things, then you belong to the wrong-wing party.   There is nothing extreme in what the left wants. 0.910691 0.0744395025074482 0.8
# 7047842 47842 Actually TS only cost us 6pts. McManus cost us another 6pts and the defense cost us 16pts. I'd also say that the worst Bronco player last night would be hard to determine with Watson, Turner, Marshall, McManus, Leary, Fowler, Anderson, Derby, Simmons and McKenzie all being eligible candidates for worst... among others of course, including the coaching if you need more choices. 0.91062266 0.10053091123700142 nan

# %%
tp_csv.iloc[103]

# %%
LSI_SIMILAR_CUTOFF=0.85
NUM_CUTOFF=9

def get_similar_docs(doc_idx):
    return sorted([(i, v) for (i,v) in enumerate(index[lsi[corpus[doc_idx]]]) if v>LSI_SIMILAR_CUTOFF], key=lambda x: -x[1])[:NUM_CUTOFF+1]

# %%
all_female_positives=submission_csv[(submission_csv['prediction']>0.5) & (tp_csv['female'] > 0.5)].index

# %%
len(all_female_positives)
# Out:
# 995

# %% [markdown]
# ## Build data subset with seed comments + neighboring comments

# %%
import tqdm

# %%
all_female_sim_doc_idx=[i for p in tqdm.notebook.tqdm(all_female_positives) for (i, _) in get_similar_docs(p)]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """Entry point for launching an IPython kernel.
# HBox(children=(IntProgress(value=0, max=995), HTML(value='')))

# %%
len(all_female_sim_doc_idx)
# Out:
# 3254

# %%
def protected_similar_docs(protected_category):
    all_protected_positives=submission_csv[(submission_csv['prediction']>0.5) & (tp_csv[protected_category] > 0.5)].index
    all_sim_doc_idx=[i for p in tqdm.notebook.tqdm(all_protected_positives) for (i, _) in get_similar_docs(p)]
    return all_sim_doc_idx

# %%
all_male_sim_doc_idx=protected_similar_docs('male')
# Out:
# HBox(children=(IntProgress(value=0, max=929), HTML(value='')))

# %%
len(all_male_sim_doc_idx)
# Out:
# 3116

# %%
all_white_sim_doc_idx=protected_similar_docs('white')
# Out:
# HBox(children=(IntProgress(value=0, max=1013), HTML(value='')))

# %%
all_black_sim_doc_idx=protected_similar_docs('black')
# Out:
# HBox(children=(IntProgress(value=0, max=605), HTML(value='')))

# %%
all_christian_sim_doc_idx=protected_similar_docs('christian')
# Out:
# HBox(children=(IntProgress(value=0, max=642), HTML(value='')))

# %%
all_muslim_sim_doc_idx=protected_similar_docs('muslim')
# Out:
# HBox(children=(IntProgress(value=0, max=676), HTML(value='')))

# %%
all_jewish_sim_doc_idx=protected_similar_docs('jewish')
# Out:
# HBox(children=(IntProgress(value=0, max=225), HTML(value='')))

# %%
pickle.dump(all_female_sim_doc_idx, open('./all_female_sim_doc_idx.p', mode='wb'))

# %%
pickle.dump(all_male_sim_doc_idx, open('./all_male_sim_doc_idx.p', mode='wb'))

# %%
pickle.dump(all_white_sim_doc_idx, open('./all_white_sim_doc_idx.p', mode='wb'))

# %%
pickle.dump(all_black_sim_doc_idx, open('./all_black_sim_doc_idx.p', mode='wb'))

# %%
pickle.dump(all_christian_sim_doc_idx, open('./all_christian_sim_doc_idx.p', mode='wb'))

# %%
pickle.dump(all_muslim_sim_doc_idx, open('./all_muslim_sim_doc_idx.p', mode='wb'))

# %%
pickle.dump(all_jewish_sim_doc_idx, open('./all_jewish_sim_doc_idx.p', mode='wb'))

# %% [markdown]
# ## Analyze correlation

# %%
from scipy.stats.stats import pearsonr

# %%
pearsonr(np.nan_to_num(ts_csv.iloc[list(all_female_sim_doc_idx)]['female']), submission_csv.iloc[list(all_female_sim_doc_idx)]['prediction'])
# Out:
# (0.5241548089013012, 7.398533097611985e-201)

# %%
pearsonr(np.nan_to_num(ts_csv['female']), submission_csv['prediction'])
# Out:
# (0.0636377388946802, 7.052652334416386e-88)

# %%
len(set(all_female_sim_doc_idx))
# Out:
# 2849

# %%
def corr(category):
    idx=set(pickle.load(open(f'./all_{category}_sim_doc_idx.p', mode='rb')))
    return pearsonr(np.nan_to_num(ts_csv.iloc[list(all_female_sim_doc_idx)][category]), submission_csv.iloc[list(all_female_sim_doc_idx)]['prediction'])

# %%
for c in ['male', 'female', 'white', 'black', 'christian', 'muslim', 'jewish']:
    print(c, corr(c))
# Out:
# male (0.24434206974151151, 5.334698275599568e-40)
# female (0.5241548089013012, 7.398533097611985e-201)
# white (0.16711264584605362, 2.729815877792574e-19)
# black (0.16628819914670226, 4.1022076555762066e-19)
# christian (0.007912226888046364, 0.672919554304298)
# muslim (0.1473211270666395, 2.7200176844588635e-15)
# jewish (0.046412233327264504, 0.013228844004021642)

# %%
CATEGORIES=['male', 'female', 'white', 'black', 'christian', 'muslim', 'jewish']

# %%
c_to_corrs={v: corr(v) for v in CATEGORIES}

# %%
c_to_corrs
# Out:
# {'black': (0.16628819914670226, 4.1022076555762066e-19),
#  'christian': (0.007912226888046364, 0.672919554304298),
#  'female': (0.5241548089013012, 7.398533097611985e-201),
#  'jewish': (0.046412233327264504, 0.013228844004021642),
#  'male': (0.24434206974151151, 5.334698275599568e-40),
#  'muslim': (0.1473211270666395, 2.7200176844588635e-15),
#  'white': (0.16711264584605362, 2.729815877792574e-19)}

# %%
c_to_corrs.keys()
# Out:
# dict_keys(['male', 'female', 'white', 'black', 'christian', 'muslim', 'jewish'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()

# %%
plt.figure(figsize=(15,10))
plt.bar(x=c_to_corrs.keys(), height=pd.DataFrame.from_dict(c_to_corrs).iloc[0])
plt.xlabel('Category')
plt.ylabel('Pearson Correlation')
plt.title('Feature-Prediction Correlation Among Similar Documents')
plt.show()

# %%
print("category,toxic_docs,all_similar_docs")
for c in CATEGORIES:
    idx=set(pickle.load(open(f'./all_{c}_sim_doc_idx.p', mode='rb')))
    print(f"{c},{len(submission_csv[(submission_csv['prediction']>0.5) & (ts_csv[c]>0.5)])},{len(set(idx))}")
# Out:
# category,toxic_docs,all_similar_docs
# male,929,2764
# female,995,2849
# white,1013,3102
# black,605,1895
# christian,642,2257
# muslim,676,2096
# jewish,225,743
